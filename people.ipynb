# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

# %%
df=pd.read_csv('E:/ml_basics/population_india_census2011.csv')

# %%
df.columns
# Out:
# Index(['Sno', 'State / Union Territory', 'Population', 'Rural population',
#        'Urban population', 'Area', 'Density', 'Gender Ratio'],
#       dtype='object')

# %%
df.head()
# Out:
#    Sno State / Union Territory  Population  Rural population  \
# 0    1           Uttar Pradesh   199812341         155317278
# 1    2             Maharashtra   112374333          61556074
# 2    3                   Bihar   104099452          92341436
# 3    4             West Bengal    91276115          62183113
# 4    5          Madhya Pradesh    72626809          52557404
#
#    Urban population                         Area                  Density  \
# 0          44495063   240,928 km2 (93,023 sq mi)    828/km2 (2,140/sq mi)
# 1          50818259  307,713 km2 (118,809 sq mi)      365/km2 (950/sq mi)
# 2          11758016    94,163 km2 (36,357 sq mi)  1,102/km2 (2,850/sq mi)
# 3          29093002    88,752 km2 (34,267 sq mi)  1,029/km2 (2,670/sq mi)
# 4          20069405  308,245 km2 (119,014 sq mi)      236/km2 (610/sq mi)
#
#    Gender Ratio
# 0           912
# 1           929
# 2           918
# 3           953
# 4           931

# %%
df=df.set_index(df.Sno)

# %%
df.head()
# Out:
#      Sno State / Union Territory  Population  Rural population  \
# Sno
# 1      1           Uttar Pradesh   199812341         155317278
# 2      2             Maharashtra   112374333          61556074
# 3      3                   Bihar   104099452          92341436
# 4      4             West Bengal    91276115          62183113
# 5      5          Madhya Pradesh    72626809          52557404
#
#      Urban population                         Area                  Density  \
# Sno
# 1            44495063   240,928 km2 (93,023 sq mi)    828/km2 (2,140/sq mi)
# 2            50818259  307,713 km2 (118,809 sq mi)      365/km2 (950/sq mi)
# 3            11758016    94,163 km2 (36,357 sq mi)  1,102/km2 (2,850/sq mi)
# 4            29093002    88,752 km2 (34,267 sq mi)  1,029/km2 (2,670/sq mi)
# 5            20069405  308,245 km2 (119,014 sq mi)      236/km2 (610/sq mi)
#
#      Gender Ratio
# Sno
# 1             912
# 2             929
# 3             918
# 4             953
# ...

# %%
del df['Sno']

# %%
df.head()
# Out:
#     State / Union Territory  Population  Rural population  Urban population  \
# Sno
# 1             Uttar Pradesh   199812341         155317278          44495063
# 2               Maharashtra   112374333          61556074          50818259
# 3                     Bihar   104099452          92341436          11758016
# 4               West Bengal    91276115          62183113          29093002
# 5            Madhya Pradesh    72626809          52557404          20069405
#
#                             Area                  Density  Gender Ratio
# Sno
# 1     240,928 km2 (93,023 sq mi)    828/km2 (2,140/sq mi)           912
# 2    307,713 km2 (118,809 sq mi)      365/km2 (950/sq mi)           929
# 3      94,163 km2 (36,357 sq mi)  1,102/km2 (2,850/sq mi)           918
# 4      88,752 km2 (34,267 sq mi)  1,029/km2 (2,670/sq mi)           953
# 5    308,245 km2 (119,014 sq mi)      236/km2 (610/sq mi)           931

# %%
df
# Out:
#                       State / Union Territory  Population  Rural population  \
# Sno
# 1                               Uttar Pradesh   199812341         155317278
# 2                                 Maharashtra   112374333          61556074
# 3                                       Bihar   104099452          92341436
# 4                                 West Bengal    91276115          62183113
# 5                              Madhya Pradesh    72626809          52557404
# 6                                  Tamil Nadu    72147030          37229590
# 7                                   Rajasthan    68548437          51500352
# 8                                   Karnataka    61095297          37469335
# 9                                     Gujarat    60439692          34694609
# 10                             Andhra Pradesh    49577103          34966693
# 11                                     Odisha    41974218          34970562
# ...

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002B4C24EC548>,
# ...
#       dtype=object)

# %%
import seaborn as sns

# %%
a=sns.barplot(data=df)

# %%
sns.barplot(x='State / Union Territory',y='Urban population',data=df)

# %%
sns.pairplot(data=df,hue='State / Union Territory',palette='rainbow')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.pairplot(data=df)

# %%
sns.jointplot(x='Population',y='State / Union Territory',data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-dd215a502aeb> in <module>
# ----> 1 sns.jointplot(x='Population',y='State / Union Territory',data=df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2299         marginal_kws.setdefault("kde", False)
#    2300         marginal_kws.setdefault("color", color)
# -> 2301         grid.plot_marginals(distplot, **marginal_kws)
#    2302
#    2303     elif kind.startswith("hex"):
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in plot_marginals(self, func, **kwargs)
#    1812         kwargs["vertical"] = True
#    1813         plt.sca(self.ax_marg_y)
# -> 1814         func(self.y, **kwargs)
#    1815
#    1816         return self
#
# ...

# %%
plt.scatter(x='State / Union Territory',y='Population',data=df,marker='+')

# %%
sns.barplot(x='State / Union Territory',y='Population',data=df)

# %%
sns.set(rc={'figure.figsize':(110.7,42.27)})

# %%
sns.set_context("talk", font_scale=2)

# %%
sns.set_context()

# %%
df.hist()
plt.show()
